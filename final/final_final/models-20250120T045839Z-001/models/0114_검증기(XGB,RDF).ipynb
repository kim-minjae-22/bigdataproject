# %%
import os
import pandas as pd
import numpy as np
import joblib
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score

# 모델 로드
XGB_model = joblib.load(r"D:\FinalTrainedModels\3rd model\xgboost_model_with_pca3rd.joblib")
RDF_model = joblib.load(r"D:\FinalTrainedModels\3rd model\randomforest_model_with_pca3rd.joblib")

# 기존 학습에서 사용했던 scaler와 PCA 로드
scaler = joblib.load(r"D:\FinalTrainedModels\3rd model\scaler_model3rd.joblib")  # 학습 시 저장된 scaler 파일
pca = joblib.load(r"D:\FinalTrainedModels\3rd model\pca_model3rd.joblib")  # 학습 시 저장된 PCA 파일

# 메타데이터 추출 함수
def extract_metadata(file_path):
    metadata = {}
    
    with open(file_path, 'r', encoding='utf-8') as file:
        lines = file.readlines()
        
        # 파일에서 메타데이터 추출
        for line in lines:
            if line.startswith('Date'):
                metadata['Date'] = line.strip().split(',')[1]
            elif line.startswith('Filename'):
                metadata['Filename'] = line.strip().split(',')[1]
            elif line.startswith('Data Label'):
                metadata['Data Label'] = line.strip().split(',')[1]
            elif line.startswith('Label No'):
                metadata['Label No'] = line.strip().split(',')[1]
            elif line.startswith('Motor Spec'):
                motor_spec = line.strip().split(',')[1:]
                metadata['Motor Spec'] = motor_spec
    
    return metadata

# 센서 데이터 추출 함수
def extract_sensor_data(file_path):
    # 파일에서 센서 데이터를 읽기
    data = pd.read_csv(file_path, skiprows=10, header=None)
    data.columns = ['time','Sensor1', 'Sensor2', 'Sensor3','']
    return data

# 피처 계산 함수
def calculate_features(data):
    features = {}

    # 절댓값 평균
    features['Mean'] = np.mean(np.abs(data))

    # 절댓값 최대값
    features['Max'] = np.max(np.abs(data))

    # RMS (Root Mean Square)
    features['RMS'] = np.sqrt(np.mean(data ** 2))

    # Skewness
    features['Skewness'] = pd.Series(data).skew()

    # Kurtosis
    features['Kurtosis'] = pd.Series(data).kurt()

    # Crest Factor
    rms = features['RMS']
    features['Crest Factor'] = features['Max'] / rms if rms != 0 else 0

    # Impulse Factor
    mean = features['Mean']
    features['Impulse Factor'] = features['Max'] / mean if mean != 0 else 0

    # Shape Factor
    features['Shape Factor'] = rms / mean if mean != 0 else 0

    return features

# 데이터 처리 함수
def load_and_process_new_data(file_path, scaler, pca, feature_names=None):
    # 메타데이터 추출
    metadata = extract_metadata(file_path)
    
    # 센서 데이터 추출
    sensor_data = extract_sensor_data(file_path)

    # 각 센서별 피처 계산
    overall_features = {'Label': metadata['Label No']}
    for sensor in ['Sensor1', 'Sensor2', 'Sensor3']:
        features = calculate_features(sensor_data[sensor].values)
        for feature_name, value in features.items():
            overall_features[f'{sensor}_{feature_name}'] = value

    # Motor Spec_Period 추가 (예시: motor spec에서 주기를 계산하여 추가)
    motor_spec_period = 1  # 예시로 1로 설정, 실제 계산 필요
    overall_features['Motor Spec_Period'] = motor_spec_period

    # 피처와 레이블을 데이터프레임으로 변환
    combined_df = pd.DataFrame([overall_features])

    # 피처 (X)와 레이블 (y) 분리
    X = combined_df.drop(columns=['Label'])
    y = combined_df['Label']

    # feature_names에 맞춰서 새 데이터의 순서를 정렬
    if feature_names:
        X = X[feature_names]  # 학습 시 사용한 특성 순서로 정렬

    # 데이터 스케일링
    X_scaled = scaler.transform(X)

    # PCA 적용
    X_pca = pca.transform(X_scaled)

    return X_pca, y

# 디렉토리 내 모든 파일 처리
def process_all_files_in_directory(directory_path, scaler, pca, XGB_model, RDF_model, feature_names=None):
    result = []  # 결과를 저장할 리스트

    for root, dirs, files in os.walk(directory_path):
        for file in files:
            if file.endswith(".csv"):  # .csv 파일을 처리
                file_path = os.path.join(root, file)
                print(f"Processing file: {file_path}")

                # 새로운 데이터에 대해 처리 및 예측 수행
                X_new_pca, y_new = load_and_process_new_data(file_path, scaler, pca, feature_names)

                # 예측 수행 (XGBOOST 모델)
                XGB_pred = XGB_model.predict(X_new_pca)
                #print(f"XGBOOST Prediction for {file}: {XGB_pred}")

                # 예측 수행 (RANDOMFOREST 모델)
                RDF_pred = RDF_model.predict(X_new_pca)
                #print(f"RandomForest Prediction for {file}: {RDF_pred}")

                # 결과를 리스트에 저장
                result.append({
                    'Filename': file,
                    'XGBOOST Prediction' : XGB_pred[0],
                    'RandomForest Prediction': RDF_pred[0],
                    'True Label': y_new.values[0]
                })
    
    # 결과를 데이터프레임으로 변환
    result_df = pd.DataFrame(result)

    # 예측값 매핑: 0 → 'N', 1 → 'E1', 2 → 'E2', 3 → 'E3', 4 → 'E4'
    label_mapping = {0: 'N', 1: 'E1', 2: 'E2', 3: 'E3', 4: 'E4'}
    result_df['XGB Prediction Label'] = result_df['XGBOOST Prediction'].map(label_mapping)
    result_df['RDF Prediction Label'] = result_df['RandomForest Prediction'].map(label_mapping)

    return result_df

# 불량 유형 비율 계산 함수
def calculate_defect_ratios(result_df):
    for model in ['XGB', 'RDF']:
        print(f"\n{model} Model 비율 계산:")

        total_count = result_df.shape[0]
        
        # 정상(N) 비율 계산
        normal_count = result_df[result_df[f'{model} Prediction Label'] == 'N'].shape[0]
        normal_ratio = normal_count / total_count if total_count > 0 else 0
        print(f"  정상 (N) 비율: {normal_ratio * 100:.2f}%")
        
        # 불량 유형별 비율 계산
        for defect_type in ['E1', 'E2', 'E3', 'E4']:
            defect_count = result_df[result_df[f'{model} Prediction Label'] == defect_type].shape[0]
            defect_ratio = defect_count / total_count if total_count > 0 else 0
            print(f"  {defect_type} 비율: {defect_ratio * 100:.2f}%")

# 학습 데이터에서 특성 이름 추출
feature_names = [
    'Sensor1_Mean', 'Sensor1_Max', 'Sensor1_RMS', 'Sensor1_Skewness', 'Sensor1_Kurtosis', 
    'Sensor1_Crest Factor', 'Sensor1_Impulse Factor', 'Sensor1_Shape Factor', 
    'Sensor2_Mean', 'Sensor2_Max', 'Sensor2_RMS', 'Sensor2_Skewness', 'Sensor2_Kurtosis', 
    'Sensor2_Crest Factor', 'Sensor2_Impulse Factor', 'Sensor2_Shape Factor', 
    'Sensor3_Mean', 'Sensor3_Max', 'Sensor3_RMS', 'Sensor3_Skewness', 'Sensor3_Kurtosis', 
    'Sensor3_Crest Factor', 'Sensor3_Impulse Factor', 'Sensor3_Shape Factor',
    'Motor Spec_Period'  # Motor Spec_Period 추가
]

# 디렉토리 경로
directory_path = r"D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량"  # 여기에 새로운 데이터 파일이 들어있는 디렉토리 경로를 입력

# 디렉토리 내 모든 파일 처리 및 결과 출력
result_df = process_all_files_in_directory(directory_path, scaler, pca, XGB_model, RDF_model, feature_names=feature_names)
print("\nPrediction Results:")
print(result_df)

# 불량 유형 비율 계산
calculate_defect_ratios(result_df)
# Out:
# C:\Users\human\anaconda3\Lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator DecisionTreeClassifier from version 1.6.0 when using version 1.5.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\human\anaconda3\Lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator RandomForestClassifier from version 1.6.0 when using version 1.5.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\human\anaconda3\Lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.6.0 when using version 1.5.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\human\anaconda3\Lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator PCA from version 1.6.0 when using version 1.5.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_031907_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_034105_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_034106_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_034107_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_034205_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_034206_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_034207_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_034305_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_034306_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_034307_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_034405_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_034406_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_034407_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_034505_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_034506_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_034507_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_035005_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_035006_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_035007_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_035105_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_035106_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_035107_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_035205_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_035206_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_035207_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_041105_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_041106_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_041107_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_041205_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_041206_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_041207_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_041305_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_041306_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_041307_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_041405_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_041406_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_041407_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_041605_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_041606_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_041607_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_041705_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_041706_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_041707_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_041805_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_041806_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_041807_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_041905_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_041906_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_041907_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_044505_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_044506_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_044507_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_044605_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_044606_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_044607_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_044705_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_044706_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_044707_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_044805_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_044806_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_044807_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_044905_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_044906_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_044907_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_051105_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_051106_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_051107_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_051205_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_051206_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_051207_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_051305_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_051306_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_051307_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_051405_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_051406_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_051407_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_051505_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_051506_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_051507_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_051605_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_051606_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_051607_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_051705_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_051706_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_051707_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_051805_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_051806_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_051807_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_051905_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_051906_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_051907_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_054205_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_054206_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_054207_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_054305_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_054306_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_054307_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_054405_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_054406_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_054407_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_054505_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_054506_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_054507_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_054605_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_054606_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_054607_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_054705_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_054706_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_054707_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_054805_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_054806_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_054807_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_054905_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_054906_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_054907_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_061405_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_061406_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_061407_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_061505_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_061506_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_061507_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_061605_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_061606_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_061607_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_061705_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_061706_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_061707_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_061805_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_061806_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_061807_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_064005_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_064006_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_064007_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_064105_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_064106_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_064107_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_064205_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_064206_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_064207_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_064305_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_064306_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_064307_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_064405_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_064406_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_064407_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_064605_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_064606_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_064607_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_064705_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_064706_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_064707_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_064805_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_064806_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_064807_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_064905_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_064906_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_064907_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_071205_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_071206_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_071207_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_071305_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_071306_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_071307_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_071405_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_071406_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_071407_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_071505_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_071506_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_071507_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_071605_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_071606_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_071607_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_072005_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_072006_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_072007_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_072105_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_072106_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_072107_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_072205_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_072206_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_072207_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_074005_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_074006_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_074007_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_074105_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_074106_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_074107_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_074205_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_074206_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_074207_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_074305_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_074306_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_074307_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_074405_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_074406_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_074407_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_074605_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_074606_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_074607_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_074705_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_074706_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_074707_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_074805_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_074806_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_074807_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_074905_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_074906_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_074907_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_081205_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_081206_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_081207_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_081305_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_081306_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_081307_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_081405_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_081406_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_081407_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_081505_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_081506_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_081507_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_081605_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_081606_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_081607_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_081705_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_081706_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_081707_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_081805_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_081806_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_081807_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_081905_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_081906_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_081907_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_084105_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_084106_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_084107_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_084205_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_084206_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_084207_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_084305_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_084306_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_084307_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_084405_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_084406_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_084407_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_084505_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_084506_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_084507_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_084705_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_084706_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_084707_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_084805_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_084806_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_084807_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_084905_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_084906_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_084907_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_091305_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_091306_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_091307_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_091405_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_091406_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_091407_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_091505_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_091506_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_091507_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_091605_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_091606_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_091607_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_091705_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_091706_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_091707_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_121005_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_121006_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_121007_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_121105_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_121106_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_121107_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_121205_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_121206_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_121207_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_121305_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_121306_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_121307_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_121405_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_121406_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_121407_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_121705_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_121706_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_121707_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_121805_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_121806_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_121807_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_121905_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_121906_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_121907_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_131205_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_131206_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_131207_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_131305_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_131306_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_131307_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_131405_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_131406_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_131407_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_131505_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_131506_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_131507_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_131605_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_131606_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_131607_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_131705_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_131706_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_131707_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_131805_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_131806_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_131807_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_131905_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_131906_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_131907_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_141605_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_141606_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_141607_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_141705_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_141706_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_141707_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_141805_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_141806_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_141807_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_141905_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_141906_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_141907_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_151405_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_151406_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_151407_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_151505_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_151506_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_151507_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_151605_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_151606_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_151607_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_151705_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_151706_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_151707_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_151805_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_151806_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_151807_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_152005_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_152006_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_152007_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_152105_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_152106_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_152107_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_152205_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_152206_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_152207_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_161505_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_161506_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_161507_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_161605_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_161606_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_161607_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_161705_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_161706_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_161707_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_161805_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_161806_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_161807_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_161905_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_161906_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_161907_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_201505_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_201506_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_201507_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_201605_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_201606_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_201607_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_201705_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_201706_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_201707_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_201805_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_201806_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_201807_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20201206_201905_002.csv
# ...
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_012008_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_014405_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_014406_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_014407_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_014505_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_014506_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_014507_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_014605_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_014606_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_014607_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_014706_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_014707_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_014708_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_014805_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_014806_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_014807_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_015005_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_015006_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_015007_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_021405_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_021406_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_021407_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_021506_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_021507_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_021508_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_021605_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_021606_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_021607_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_021805_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_021806_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_021807_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_022005_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_022006_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_022007_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_024405_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_024406_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_024407_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_024605_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_024606_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_024607_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_024705_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_024706_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_024707_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_024708_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_024905_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_024906_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_024907_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_025006_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_025007_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_025008_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_031305_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_031306_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_031307_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_031505_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_031506_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_031507_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_031606_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_031607_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_031608_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_031705_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_031706_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_031707_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_031806_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_031807_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_031808_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_031905_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_031906_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_031907_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_034305_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_034306_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_034307_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_034505_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_034506_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_034507_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_034606_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_034607_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_034608_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_034705_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_034706_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_034707_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_034805_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_034806_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_034807_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_034906_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_034907_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_034908_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_035005_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_035006_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_035007_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_041205_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_041206_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_041207_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_041306_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_041307_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_041308_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_041405_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_041406_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_041407_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_041506_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_041507_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_041508_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_041605_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_041606_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_041607_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_041705_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_041706_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_041707_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_041708_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_041905_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_041906_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_041907_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_042006_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_042007_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_042008_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_044205_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_044206_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_044207_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_044405_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_044406_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_044407_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_044506_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_044507_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_044508_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_044605_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_044606_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_044607_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_044805_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_044806_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_044807_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_044905_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_044906_002.csv
# Processing file: D:\기계시설물 고장 예지 센서\Training\current\남은파일\L-DSF-01\축정렬불량\STFCB-20201012-0105-0137_20210119_044907_002.csv

# %% [markdown]
# # 시각화 자료

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import os

# 한글 폰트 설정 (필요한 경우)
plt.rcParams['font.family'] = 'Malgun Gothic'  # 윈도우
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

# 저장 경로 설정
output_dir = r"C:\Users\human\Desktop\프로젝트 관련\이미지들"  # 저장할 디렉토리 경로
os.makedirs(output_dir, exist_ok=True)  # 디렉토리가 없으면 생성

# 불량 유형 비율 시각화
def visualize_defect_ratios(result_df, output_dir):
    for model in ['XGB', 'RDF']:
        # 불량 유형 비율 계산
        defect_counts = result_df[f'{model} Prediction Label'].value_counts()
        defect_labels = defect_counts.index
        defect_values = defect_counts.values

        # 막대그래프
        plt.figure(figsize=(10, 6))
        sns.barplot(x=defect_labels, y=defect_values, palette="viridis")
        plt.title(f"{model} Model - 예측 결과 분포", fontsize=16)
        plt.xlabel("예측 라벨", fontsize=14)
        plt.ylabel("파일 개수", fontsize=14)
        plt.xticks(fontsize=12)
        plt.yticks(fontsize=12)

        # 저장
        bar_output_path = os.path.join(output_dir, f"{model}_Prediction_Bar.jpg")
        plt.savefig(bar_output_path, format="jpg", dpi=300)
        print(f"Saved bar chart: {bar_output_path}")
        plt.close()

        # 파이차트
        plt.figure(figsize=(8, 8))
        plt.pie(defect_values, labels=defect_labels, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("viridis", len(defect_labels)))
        plt.title(f"{model} Model - 예측 결과 비율", fontsize=16)

        # 저장
        pie_output_path = os.path.join(output_dir, f"{model}_Prediction_Pie.jpg")
        plt.savefig(pie_output_path, format="jpg", dpi=300)
        print(f"Saved pie chart: {pie_output_path}")
        plt.close()

# 모델 간 결과 비교 시각화
def visualize_model_comparison(result_df, output_dir):
    # XGBoost vs RandomForest의 예측 결과 비교
    comparison = result_df[['XGB Prediction Label', 'RDF Prediction Label']].value_counts().reset_index()
    comparison.columns = ['XGB Prediction Label', 'RDF Prediction Label', 'Count']

    plt.figure(figsize=(12, 8))
    sns.heatmap(comparison.pivot("XGB Prediction Label", "RDF Prediction Label", "Count"),
                annot=True, fmt='d', cmap='Blues')
    plt.title("XGBoost와 RandomForest 모델의 예측 결과 비교", fontsize=16)
    plt.xlabel("RandomForest Prediction", fontsize=14)
    plt.ylabel("XGBoost Prediction", fontsize=14)
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)

    # 저장
    heatmap_output_path = os.path.join(output_dir, "Model_Comparison_Heatmap.jpg")
    plt.savefig(heatmap_output_path, format="jpg", dpi=300)
    print(f"Saved heatmap: {heatmap_output_path}")
    plt.close()

# 함수 실행
visualize_defect_ratios(result_df, output_dir)  # 불량 유형 비율 시각화 및 저장
visualize_model_comparison(result_df, output_dir)  # 모델 간 예측 비교 시각화 및 저장
# Out:
# C:\Users\human\AppData\Local\Temp\ipykernel_6524\1611297124.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=defect_labels, y=defect_values, palette="viridis")
# Saved bar chart: C:\Users\human\Desktop\프로젝트 관련\이미지들\XGB_Prediction_Bar.jpg
# Saved pie chart: C:\Users\human\Desktop\프로젝트 관련\이미지들\XGB_Prediction_Pie.jpg
# C:\Users\human\AppData\Local\Temp\ipykernel_6524\1611297124.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=defect_labels, y=defect_values, palette="viridis")
# Saved bar chart: C:\Users\human\Desktop\프로젝트 관련\이미지들\RDF_Prediction_Bar.jpg
# Saved pie chart: C:\Users\human\Desktop\프로젝트 관련\이미지들\RDF_Prediction_Pie.jpg
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 70
#      68 # 함수 실행
#      69 visualize_defect_ratios(result_df, output_dir)  # 불량 유형 비율 시각화 및 저장
# ---> 70 visualize_model_comparison(result_df, output_dir)
#
# Cell In[6], line 54, in visualize_model_comparison(result_df, output_dir)
#      51 comparison.columns = ['XGB Prediction Label', 'RDF Prediction Label', 'Count']
#      53 plt.figure(figsize=(12, 8))
# ---> 54 sns.heatmap(comparison.pivot("XGB Prediction Label", "RDF Prediction Label", "Count"),
#      55             annot=True, fmt='d', cmap='Blues')
#      56 plt.title("XGBoost와 RandomForest 모델의 예측 결과 비교", fontsize=16)
#      57 plt.xlabel("RandomForest Prediction", fontsize=14)
#
# TypeError: DataFrame.pivot() takes 1 positional argument but 4 were given
